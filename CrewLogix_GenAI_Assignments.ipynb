# %% [markdown]
# <a href="https://colab.research.google.com/github/Syed-Irtaza/CrewLogix_GenAI_Assignment/blob/main/CrewLogix_GenAI_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Creating an CLI-based ChatBot using google gemini-api**

# %%
from google import genai
from google.colab import userdata
import json

# %%
from google.colab import userdata
api_key = userdata.get('GEMINI_API_KEY')

# %%
user_prompt = input("Ask Anything! ")

while user_prompt != "quit":
  agent_response(user_prompt)
  user_prompt = input("Ask Anything! ")
# Out:
# Ask Anything! what is C++ in 5 words
# Powerful, fast, versatile programming language.
#
# Ask Anything! quit

# %%
messages=[

]

# %%
def agent_response(prompt):
  client = genai.Client(api_key = api_key)

  response = client.models.generate_content_stream(
    model="gemini-3-flash-preview",
    contents=f"{prompt}",
  )
  full_text = ""
  for chunk in response:
        if chunk.text:
            print(chunk.text, end="", flush=True) # Print immediately
            full_text += chunk.text

  messages.append({"user_prompt":prompt,"agent_response":full_text})
  print("\n")

# %%
def display():
  print(json.dumps(messages,indent=4))

# %%
display()
# Out:
# [
#     {
#         "user_prompt": "what is JS explain in few words",
#         "agent_response": "**JavaScript (JS)** is the programming language used to make websites **interactive**. \n\nIf a website were a house:\n*   **HTML** is the structure (walls).\n*   **CSS** is the look (paint).\n*   **JavaScript** is the electricity (light switches and appliances).\n\nIn short: It handles everything that **moves, changes, or reacts** on a webpage."
#     },
#     {
#         "user_prompt": "write a story on Ali in 5 words",
#         "agent_response": "Ali climbed the highest mountain."
#     },
#     {
#         "user_prompt": "who is shahzad abbas tell me in 2 words",
#         "agent_response": "**News anchor.**"
#     },
#     {
#         "user_prompt": "what is C++ in 5 words",
#         "agent_response": "Powerful, fast, versatile programming language."
#     }
# ]
